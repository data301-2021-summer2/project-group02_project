# %%
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append('..\Jimmy\scripts')
import project_functions

# %%
df = project_functions.clean_data("allBirthData.csv")
display(df)
# Out:
#         State  Month  Year  stateBirths
# 1           1      1  1985         5027
# 2           1      2  1985         4627
# 3           1      3  1985         4738
# 4           1      4  1985         4626
# 5           1      5  1985         4834
# ...       ...    ...   ...          ...
# 321471     55     12  2015         5632
# 321472     55     12  2015         5632
# 321473     55     12  2015         5632
# 321474     55     12  2015         5632
# 321475     56     12  2015          661
#
# [284466 rows x 4 columns]

# %%
df.describe().T
# Out:
#                 count          mean           std     min     25%     50%  \
# State        284466.0     27.498098     14.757267     1.0    15.0    27.0
# Month        284466.0      6.505407      3.447227     1.0     4.0     7.0
# Year         284466.0   1996.042360     10.099483  1985.0  1987.0  1993.0
# stateBirths  284466.0  11091.049194  10305.436359   417.0  4661.0  7251.0
#
#                  75%      max
# State           40.0     56.0
# Month            9.0     12.0
# Year          2005.0   2015.0
# stateBirths  13433.0  55066.0

# %%
corr=df.corr()
sns.heatmap(corr,xticklabels=corr.columns, yticklabels=corr.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
df.boxplot('Year')
# Out:
# <AxesSubplot:>

# %%
df.boxplot('State')
# Out:
# <AxesSubplot:>

# %%
df.boxplot('Month')
# Out:
# <AxesSubplot:>

# %%
df.boxplot('stateBirths')
# Out:
# <AxesSubplot:>

# %%
hist = df.hist(bins=10,figsize =(10,10))

# %%
boxplot = df.boxplot(grid=False, vert=False,fontsize=15)

# %%
state_births_month, df_state_year, df_state_births=project_functions.load_and_process("allBirthData.csv")
# 
x=df_state_births.index
y=df_state_births["births"]

plt.figure(figsize=(10,8))
sns.barplot(x,y)
plt.xticks(fontsize=8)
plt.xlabel("State")
plt.ylabel("Births")
plt.title("State-births")
plt.show()
# Out:
# C:\Users\Jimmy\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# scatterplot
df_state_births=df_state_births.sort_values(by="births",ascending=False)


series_plot1=df_state_births.index[0:13]
plt.figure(figsize=(10,8))
plt.xlabel("Year")
plt.ylabel("Births")
sns.scatterplot(data=df_state_year.loc[:,series_plot1])
plt.show()

series_plot2=df_state_births.index[13:26]
plt.figure(figsize=(10,8))
plt.xlabel("Year")
plt.ylabel("Births")
sns.scatterplot(data=df_state_year.loc[:,series_plot2])
plt.show()

series_plot3=df_state_births.index[26:39]
plt.figure(figsize=(10,8))
plt.xlabel("Year")
plt.ylabel("Births")

sns.scatterplot(data=df_state_year.loc[:,series_plot3])

plt.xlabel("Year")
plt.ylabel("Births")
plt.show()

series_plot4=df_state_births.index[39:]
plt.figure(figsize=(10,8))
plt.xlabel("Year")
plt.ylabel("Births")
sns.scatterplot(data=df_state_year.loc[:,series_plot4])
plt.show()

# %%
# 2007
y=df_state_year.loc[2007]
plt.figure(figsize=(15,10))
sns.barplot(x,y)
plt.xlabel("Stare")
plt.ylabel("Births")
plt.show()



# 2008
y=df_state_year.loc[2008]
plt.figure(figsize=(15,10))
plt.xlabel("State")
plt.ylabel("Births")
sns.barplot(x,y)
plt.show()
# Out:
# C:\Users\Jimmy\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Jimmy\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
