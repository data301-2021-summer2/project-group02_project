# %%
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append('..\Jimmy\scripts')
import project_functions

# %% [markdown]
# ### Load Data

# %%
df = project_functions.clean_data("allBirthData.csv")
display(df)
# Out:
#       State Month  Year stateBirths
# 0         1     1  1985        5027
# 1         1     2  1985        4627
# 2         1     3  1985        4738
# 3         1     4  1985        4626
# 4         1     5  1985        4834
# ...     ...   ...   ...         ...
# 18523    51    12  2015        8807
# 18524    53    12  2015        7311
# 18525    54    12  2015        1660
# 18526    55    12  2015        5632
# 18527    56    12  2015         661
#
# [18528 rows x 4 columns]

# %% [markdown]
# ### Explanatory Data Analysis (EDA)

# %%
df.describe().T
# Out:
#                 count          mean           std     min     25%     50%  \
# State        284466.0     27.498098     14.757267     1.0    15.0    27.0
# Month        284466.0      6.505407      3.447227     1.0     4.0     7.0
# Year         284466.0   1996.042360     10.099483  1985.0  1987.0  1993.0
# stateBirths  284466.0  11091.049194  10305.436359   417.0  4661.0  7251.0
#
#                  75%      max
# State           40.0     56.0
# Month            9.0     12.0
# Year          2005.0   2015.0
# stateBirths  13433.0  55066.0

# %%
corr=df.corr()
sns.heatmap(corr,xticklabels=corr.columns, yticklabels=corr.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
df.boxplot('Year')
# Out:
# <AxesSubplot:>

# %%
df.boxplot('State')
# Out:
# <AxesSubplot:>

# %%
df.boxplot('Month')
# Out:
# <AxesSubplot:>

# %%
df.boxplot('stateBirths')
# Out:
# <AxesSubplot:>

# %%
hist = df.hist(bins=10,figsize =(10,10))

# %%
boxplot = df.boxplot(grid=False, vert=False,fontsize=15)

# %% [markdown]
# ### Graphs of State Births

# %%
state_births_month, df_state_year, df_state_births=project_functions.load_and_process("allBirthData.csv")
# 
x=df_state_births.index
y=df_state_births["births"]

plt.figure(figsize=(10,8))
sns.barplot(x,y)
plt.xticks(fontsize=8)
plt.xlabel("State")
plt.ylabel("Births")
plt.title("State-births")
plt.savefig('Bar Graph of All State-birth.png')
plt.show()
# Out:
# c:\users\guofei\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Scatterplot of 51 states divided into 4 graphs. Yearly states births are shown in differnt points.

# %%
# scatterplot
df_state_births=df_state_births.sort_values(by="births",ascending=False)


series_plot1=df_state_births.index[0:13]
plt.figure(figsize=(10,8))
plt.xlabel("Year")
plt.ylabel("Births")
plt.title("13 states' births")
sns.scatterplot(data=df_state_year.loc[:,series_plot1])
plt.savefig('Scatter-Graph-1,13-States-birth.png')
plt.show()

series_plot2=df_state_births.index[13:26]
plt.figure(figsize=(10,8))
plt.xlabel("Year")
plt.ylabel("Births")
plt.title("13 states' births")
sns.scatterplot(data=df_state_year.loc[:,series_plot2])
plt.savefig('Scatter-Graph-2,13-States-birth.png')
plt.show()

series_plot3=df_state_births.index[26:39]
plt.figure(figsize=(10,8))
sns.scatterplot(data=df_state_year.loc[:,series_plot3])
plt.xlabel("Year")
plt.ylabel("Births")
plt.title("13 states' births")
plt.savefig('Scatter-Graph-3,13-States-birth.png')
plt.show()

series_plot4=df_state_births.index[39:]
plt.figure(figsize=(10,8))
plt.xlabel("Year")
plt.ylabel("Births")
plt.title("12 states' births")
sns.scatterplot(data=df_state_year.loc[:,series_plot4])
plt.savefig('Scatter-Graph-4,12-States-birth.png')
plt.show()

# %%
# 2007
y=df_state_year.loc[2007]
plt.figure(figsize=(15,10))
sns.barplot(x,y)
plt.xlabel("Stare")
plt.ylabel("Births")
plt.savefig('Bar Graph of All State-birth in 2007.png')
plt.show()



# 2008
y=df_state_year.loc[2008]
plt.figure(figsize=(15,10))
plt.xlabel("State")
plt.ylabel("Births")
sns.barplot(x,y)
plt.savefig('Bar Graph of All State-birth in 2008.png')
plt.show()
# Out:
# c:\users\guofei\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\users\guofei\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
## We can use variables to present the population demographic of USA counties and determine the highest count of birth from 1985-2015 for each year.## 

## Also we will determine which country has increase most population in the period of 1985-2015. ##
